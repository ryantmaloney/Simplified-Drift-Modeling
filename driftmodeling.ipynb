# %%
import simpledrift as sd
import imp
imp.reload(sd)
# Out:
# <module 'simpledrift' from '/Users/ryanmaloney/Documents/GitHub/Simplified-Drift-Modeling/simpledrift.py'>

# %%
import simpledrift as sd
import imp
imp.reload(sd)

#driftmodeling(flynum, numberofbins, numberofdays, prefmean, prefvariance, envimean, envivariance, driftvariance, gain, per)
flynum=1000
numberofbins=100
numberofdays=30
prefmean=0
prefvariance=10
envimean=0
envivariance= .1
driftvariance=.001
gain=.4
per=20
deathrate=.95
birthrate=1.05
sd.driftmodeling(flynum, numberofbins, numberofdays, prefmean, prefvariance, envimean, envivariance, driftvariance, gain, per,deathrate,birthrate)

# %%
import simpledrift as sd
import imp
imp.reload(sd)

#driftmodeling(flynum, numberofbins, numberofdays, prefmean, prefvariance, envimean, envivariance, driftvariance, gain, per)
flynum=1000
numberofbins=100
numberofdays=30
prefmean=0
prefvariance=1
envimean=0
envivariance= .1
driftvariance=.001
gain=.4
per=20
deathrate=.90
birthrate=3
sd.driftmodeling(flynum, numberofbins, numberofdays, prefmean, prefvariance, envimean, envivariance, driftvariance, gain, per,deathrate,birthrate)

# %%
import simpledrift as sd
import imp
imp.reload(sd)

#driftmodeling(flynum, numberofbins, numberofdays, prefmean, prefvariance, envimean, envivariance, driftvariance, gain, per)
flynum=1
numberofbins=100
numberofdays=30
prefmean=0
prefvariance=.03
envimean=0
envivariance= .1
driftvariance=.001
gain=.4
per=20
deathrate=1
birthrate=24

sd.driftmodeling(flynum, numberofbins, numberofdays, prefmean, prefvariance, envimean, envivariance, driftvariance, gain, per,deathrate,birthrate)

# %%
import simpledrift as sd
import imp
imp.reload(sd)

#driftmodeling(flynum, numberofbins, numberofdays, prefmean, prefvariance, envimean, envivariance, driftvariance, gain, per)
flynum=1
numberofbins=100
numberofdays=30
prefmean=0
prefvariance=.001
envimean=0
envivariance= .1
driftvariance=.05
gain=.4
per=20
deathrate=1
birthrate=24
sd.driftmodeling(flynum, numberofbins, numberofdays, prefmean, prefvariance, envimean, envivariance, driftvariance, gain, per,deathrate,birthrate)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-162-cebc42512908> in <module>
#      16 deathrate=1
#      17 birthrate=24
# ---> 18 sd.driftmodeling(flynum, numberofbins, numberofdays, prefmean, prefvariance, envimean, envivariance, driftvariance, gain, per,deathrate,birthrate)
#
# ~/Documents/GitHub/Simplified-Drift-Modeling/simpledrift.py in driftmodeling(flynum, numberofbins, numberofdays, prefmean, prefvariance, envimean, envivariance, driftvariance, gain, per, deathrate, birthrate)
#      29         pref[:,t]=np.multiply(pref[:,t], envi[:,t]) # Multiplying the preference to the environment
#      30     fig, (ax0, ax1, ax2) = plt.subplots(3, 1)
# ---> 31     fig.figsize([8,8])
#      32     c=ax0.pcolormesh(envi)
#      33     fig.colorbar(c,ax=ax0)
#
# AttributeError: 'Figure' object has no attribute 'figsize'

# %%
import simpledrift as sd
import imp
imp.reload(sd)

#driftmodeling(flynum, numberofbins, numberofdays, prefmean, prefvariance, envimean, envivariance, driftvariance, gain, per)
flynum=1000
numberofbins=100
numberofdays=30
prefmean=0
prefvariance=.001
envimean=0
envivariance= .1
driftvariance=.3
gain=.4
per=20
deathrate=1
birthrate=100
sd.driftmodeling(flynum, numberofbins, numberofdays, prefmean, prefvariance, envimean, envivariance, driftvariance, gain, per,deathrate,birthrate)
