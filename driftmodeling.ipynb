# %%
import simpledrift as sd
import imp
imp.reload(sd)
# Out:
# <module 'simpledrift' from '/Users/athenaye/Documents/GitHub/Simplified-Drift-Modeling/simpledrift.py'>

# %%
import simpledrift as sd
import imp
imp.reload(sd)

#driftmodeling(flynum, numberofbins, numberofdays, prefmean, prefvariance, envimean, envivariance, driftvariance, gain, per)
flynum=1000
numberofbins=100
numberofdays=100
prefmean=[100,100]
prefvariance=[100,100]
envimean=0
envivariance=.1
driftvariance=[.1,10]
gain=.4
per=20
deathrate=1
birthrate=1
matureage=0
bh=0
drift=0
sd.driftmodeling(flynum, numberofbins, numberofdays, prefmean, prefvariance, envimean, envivariance, driftvariance, gain, per,deathrate,birthrate,matureage)
# Out:
# [6.06786463e+07 3.49285548e+08 1.93019150e+09 1.02398856e+10
#  5.21512245e+10 2.54981201e+11 1.19681006e+12 5.39279845e+12
#  2.33277197e+13 9.68712095e+13 3.86165311e+14 1.47772682e+15
#  5.42794024e+15 1.91364156e+16 6.47465181e+16 2.10194605e+17
#  6.54574945e+17 1.95464379e+18 5.59408651e+18 1.53343438e+19
#  4.02284535e+19 1.00909866e+20 2.41782102e+20 5.52774010e+20
#  1.20467052e+21 2.50044138e+21 4.94013466e+21 9.28862341e+21
#  1.66275675e+22 2.83792357e+22 4.63434107e+22 7.29249279e+22
#  1.11868361e+23 1.69601653e+23 2.56377712e+23 3.85415676e+23
#  5.68793684e+23 8.11241055e+23 1.10496678e+24 1.42832578e+24
#  1.74917294e+24 2.03170916e+24 2.24428133e+24 2.36542572e+24
#  2.38650571e+24 2.31096825e+24 2.15157564e+24 1.92724573e+24
#  1.66037671e+24 1.37455112e+24 1.09217419e+24 8.32020066e+23
#  6.07225776e+23 4.24386680e+23 2.84008125e+23 1.82022214e+23
#  1.11756586e+23 6.57559298e+22 3.70910443e+22 2.00641134e+22
# ...
