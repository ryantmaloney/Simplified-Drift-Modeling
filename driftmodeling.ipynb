# %%
import simpledrift as sd
import imp
imp.reload(sd)
# Out:
# <module 'simpledrift' from '/Users/athenaye/Documents/GitHub/Simplified-Drift-Modeling/simpledrift.py'>

# %%
import simpledrift as sd
import imp
imp.reload(sd)
import matrixmaker as mm
imp.reload(mm)

#driftmodeling(flynum, numberofbins, numberofdays, prefmean, prefvariance, envimean, envivariance, driftvariance, gain, per)
flynum=1000
numberofbins=100
numberofdays=150
prefmean=[0,0]

x=0.1
y=0.05

#one run that has x, 2x, 3x, etc all y
#one run that has y, 2y, 3y, etc all x

prefvariance=[x,2*x]
envimean=0
envivariance=.25
driftvariance=[y,2y]
gain=.4
per=20
maxsurvivalrate=1
birthrate=40
matureage=10
percentbh=0.01

sd.driftmodeling(flynum, numberofbins, numberofdays, prefmean, prefvariance, envimean, envivariance, driftvariance, gain, per,maxsurvivalrate,birthrate,matureage, percentbh)
finalpop=sd.driftmodeling(flynum, numberofbins, numberofdays, prefmean, prefvariance, envimean, envivariance, driftvariance, gain, per,maxsurvivalrate,birthrate,matureage, percentbh)

# %%
import matrixmaker as mm
import imp
imp.reload(mm)

flynum=1000
numberofbins=100
numberofdays=150
prefmean=0
prefvariance=
envimean=0
envivariance=.25
driftvariance=
gain=.4
per=20
maxsurvivalrate=1
birthrate=40
matureage=10
percentbh=0.01

bhlower=0
bhupper=5
driftlower=0
driftupper=5

sd.driftmodeling(flynum, numberofbins, numberofdays, prefmean, prefvariance, envimean, envivariance, driftvariance, gain, per,maxsurvivalrate,birthrate,matureage, percentbh)
finalpop=sd.driftmodeling(flynum, numberofbins, numberofdays, prefmean, prefvariance, envimean, envivariance, driftvariance, gain, per,maxsurvivalrate,birthrate,matureage, percentbh)
mm.matrixmaker(driftlower, driftupper, bhlower, bhupper)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-96a3934b4d0c> in <module>
#       7 numberofdays=150
#       8 prefmean=0
# ----> 9 prefvariance=f
#      10 envimean=0
#      11 envivariance=.25
#
# NameError: name 'f' is not defined

# %%
import numpy as np
finalpop

# finalpop2=np.reshape(finalpop,(1,3))
# finalpop2

# finaltest=np.random.rand(1,3)

# finalpop2
# # finaltest
# np.log(finalpop2)
# Out:
# array([11857.40883607, 11857.40883607, 11857.40883607, 11857.40883607,
#        11857.40883607])

# %%
import simpledrift as sd
import heatmap as hm
import imp
imp.reload(hm)

hm.heatmap(matrix)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-004192eebf7e> in <module>
#       4 imp.reload(hm)
#       5
# ----> 6 hm.heatmap(finalpop2)
#
# AttributeError: module 'heatmap' has no attribute 'heatmap'
