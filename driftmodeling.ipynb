# %%
import simpledrift as sd
import imp
imp.reload(sd)
# Out:
# <module 'simpledrift' from '/Users/athenaye/Documents/GitHub/Simplified-Drift-Modeling/simpledrift.py'>

# %%
import simpledrift as sd
import imp
imp.reload(sd)

#driftmodeling(flynum, numberofbins, numberofdays, prefmean, prefvariance, envimean, envivariance, driftvariance, gain, per)
flynum=1000
numberofbins=100
numberofdays=30
prefmean=0
prefvariance=.03
envimean=0
envivariance=.1
driftvariance=.000000001
gain=.4
per=20
deathrate=1
birthrate=4.5
matureage=0
sd.driftmodeling(flynum, numberofbins, numberofdays, prefmean, prefvariance, envimean, envivariance, driftvariance, gain, per,deathrate,birthrate,matureage)
# Out:
# 11822.472793043946
# 452.8167185542236
# 29367.908332168503
# 186.90540482377844
# 12174.681831396229
# 8.805838438617508
# 572.1667585323828
# 0.07707386343024339
# 5.005945984660044
# 0.00041186945420648594
# 0.026761564182050158
# 5.439615859888809e-06
# 0.00035432679136059817
# 4.653795084183898e-07
# 3.0182681387158848e-05
# 2.885650575924509e-07
# 1.8763538983254505e-05
# 7.919434428808084e-07
# 5.160492572238084e-05
# 3.934856490308927e-06
# 0.00025585853590665323
# 9.739878692406098e-06
# 0.0006316901582571997
# 4.011231492414128e-06
# 0.0002612844032962161
# 1.8874317485062988e-07
# 1.226374652478296e-05
# 1.649973963111532e-09
# 1.0716577796709664e-07
# 8.801501696066175e-12
# 5.718849750377752e-10
# 1.1592232504780697e-13
# 7.550971711831379e-12
# 9.887828383205389e-15
# 6.41285592301771e-13
# 6.121061245028285e-15
# 3.980134401864642e-13
# 1.6795900127141865e-14
# 1.094460957147079e-12
# 8.345717179911397e-14
# 5.426685786386808e-12
# 2.065801276568398e-13
# 1.3397973183596684e-11
# 8.50770325673993e-14
# 5.5417648496789065e-12
# 4.00318614027078e-15
# 2.6011038626778327e-13
# 3.4995450403374503e-17
# 2.272953847534785e-15
# 1.8667718842804093e-19
# 1.2129507319416587e-17
# 2.4586773640700666e-21
# 1.6015382038754617e-19
# 2.0971784036185035e-22
# 1.3601472867503336e-20
# 1.2982585270203317e-22
# 8.441744362719347e-21
# 3.562359480736496e-22
# 0.008491159001096094
# 0.00670308999815461

# %%
import simpledrift as sd
import imp
imp.reload(sd)

#driftmodeling(flynum, numberofbins, numberofdays, prefmean, prefvariance, envimean, envivariance, driftvariance, gain, per)
flynum=1000
numberofbins=100
numberofdays=30
prefmean=0
prefvariance=1
envimean=0
envivariance= .1
driftvariance=.001
gain=.4
per=20
deathrate=.90
birthrate=3
sd.driftmodeling(flynum, numberofbins, numberofdays, prefmean, prefvariance, envimean, envivariance, driftvariance, gain, per,deathrate,birthrate)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-bf3d49181d84> in <module>
#      16 deathrate=.90
#      17 birthrate=3
# ---> 18 sd.driftmodeling(flynum, numberofbins, numberofdays, prefmean, prefvariance, envimean, envivariance, driftvariance, gain, per,deathrate,birthrate)
#
# TypeError: driftmodeling() missing 1 required positional argument: 'matureage'

# %%
import simpledrift as sd
import imp
imp.reload(sd)

#driftmodeling(flynum, numberofbins, numberofdays, prefmean, prefvariance, envimean, envivariance, driftvariance, gain, per)
flynum=1
numberofbins=100
numberofdays=30
prefmean=0
prefvariance=.03
envimean=0
envivariance= .1
driftvariance=.001
gain=.4
per=20
deathrate=1
birthrate=24

sd.driftmodeling(flynum, numberofbins, numberofdays, prefmean, prefvariance, envimean, envivariance, driftvariance, gain, per,deathrate,birthrate)
# Out:
# 0.4528167185542236
# 0.9997582460617016
# 0.2658987263488653
# 0.011716536962602848
# 0.00023885007241745236
# 8.276115199416002e-06
# 1.395518292533997e-06
# 1.791246290446908e-06
# 1.402892847077376e-05
# 0.00025857576242187567
# 0.002918447446531659
# 0.006472373354680702
# 0.001723284487581302
# 7.59446693520473e-05
# 1.5482170855495839e-06
# 5.3645645953411284e-08
# 9.045746641036171e-09
# 1.1610908649292635e-08
# 9.093615870699952e-08
# 1.6761002729765054e-06
# 1.8917513595901335e-05
# 4.195422845905169e-05
# 1.1170411088876513e-05
# 4.92276918166975e-07
# 1.0035615956069491e-08
# 3.4773359984759684e-10
# 5.863495511879088e-11
# 7.526245588740806e-11
# 5.894524571660326e-10

# %%
import simpledrift as sd
import imp
imp.reload(sd)

#driftmodeling(flynum, numberofbins, numberofdays, prefmean, prefvariance, envimean, envivariance, driftvariance, gain, per)
flynum=1
numberofbins=100
numberofdays=60
prefmean=0
prefvariance=.001
envimean=0
envivariance= .1
driftvariance=.001
gain=.4
per=40
deathrate=.5
birthrate=0
sd.driftmodeling(flynum, numberofbins, numberofdays, prefmean, prefvariance, envimean, envivariance, driftvariance, gain, per,deathrate,birthrate)

# %%
import simpledrift as sd
import imp
imp.reload(sd)

#driftmodeling(flynum, numberofbins, numberofdays, prefmean, prefvariance, envimean, envivariance, driftvariance, gain, per)
flynum=1000
numberofbins=100
numberofdays=30
prefmean=0
prefvariance=.001
envimean=0
envivariance= .1
driftvariance=.1
gain=.4
per=20
deathrate=1
birthrate=24
sd.driftmodeling(flynum, numberofbins, numberofdays, prefmean, prefvariance, envimean, envivariance, driftvariance, gain, per,deathrate,birthrate)
# Out:
# Traceback (most recent call last):
#
#   File "/Users/ryanmaloney/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-250-7d1cc8e5ec16>", line 3, in <module>
#     imp.reload(sd)
#
#   File "/Users/ryanmaloney/anaconda3/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#
#   File "/Users/ryanmaloney/anaconda3/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#
#   File "<frozen importlib._bootstrap_external>", line 724, in exec_module
#
#   File "<frozen importlib._bootstrap_external>", line 860, in get_code
#
#   File "<frozen importlib._bootstrap_external>", line 791, in source_to_code
#
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#
#   File "/Users/ryanmaloney/Documents/GitHub/Simplified-Drift-Modeling/simpledrift.py", line 37
#     fig.suptitle('Bet-hedge variance: '+str(prefvariance)', Drift variance: '+str(driftvariance), fontsize=16)
#                                                                             ^
# SyntaxError: invalid syntax

# %%
# Out:
# /Users/ryanmaloney/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
# nan

# %%
['hi'+' boss']
# Out:
# ['hi boss']
