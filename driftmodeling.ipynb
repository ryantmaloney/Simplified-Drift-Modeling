# %%
import simpledrift as sd
import imp
imp.reload(sd)
# Out:
# <module 'simpledrift' from '/Users/athenaye/Documents/GitHub/Simplified-Drift-Modeling/simpledrift.py'>

# %%
import simpledrift as sd
import imp
imp.reload(sd)

#driftmodeling(flynum, numberofbins, numberofdays, prefmean, prefvariance, envimean, envivariance, driftvariance, gain, per)
flynum=1000
numberofbins=100
numberofdays=150
prefmean=[0,0,0]

x=0.5
y=0.05

prefvariance=[0.1*x,.5*x,x]
envimean=0
envivariance=.25
driftvariance=[y,y,y]
gain=.4
per=20
deathrate=1
birthrate=40
matureage=10
percentbh=0.01
sd.driftmodeling(flynum, numberofbins, numberofdays, prefmean, prefvariance, envimean, envivariance, driftvariance, gain, per,deathrate,birthrate,matureage, percentbh)
# Out:
# 1000.0
# /Users/athenaye/Documents/GitHub/Simplified-Drift-Modeling/simpledrift.py:90: RuntimeWarning: divide by zero encountered in log
#   ax2.plot(np.log(np.sum(pref,axis=(0,2))))
# 999.9999999999998
# /Users/athenaye/Documents/GitHub/Simplified-Drift-Modeling/simpledrift.py:90: RuntimeWarning: divide by zero encountered in log
#   ax2.plot(np.log(np.sum(pref,axis=(0,2))))
# 1000.0
# /Users/athenaye/Documents/GitHub/Simplified-Drift-Modeling/simpledrift.py:90: RuntimeWarning: divide by zero encountered in log
#   ax2.plot(np.log(np.sum(pref,axis=(0,2))))
# array([   59918.51586118, 33107586.35984799,   305469.74572216])

# %%
import simpledrift as sd
import imp
imp.reload(sd)

#driftmodeling(flynum, numberofbins, numberofdays, prefmean, prefvariance, envimean, envivariance, driftvariance, gain, per)
flynum=1000
numberofbins=100
numberofdays=150
prefmean=[0,0,0]

x=0.3
y=0.05

prefvariance=[x,1.5*x,x]
envimean=0
envivariance=.25
driftvariance=[y,y,0.7*y]
gain=.4
per=20
deathrate=1
birthrate=40
matureage=10
percentbh=0.01
abc=sd.driftmodeling(flynum, numberofbins, numberofdays, prefmean, prefvariance, envimean, envivariance, driftvariance, gain, per,deathrate,birthrate,matureage, percentbh)
# Out:
# 1000.0
# /Users/athenaye/Documents/GitHub/Simplified-Drift-Modeling/simpledrift.py:86: RuntimeWarning: divide by zero encountered in log
#   ax2.plot(np.log(np.sum(pref,axis=(0,2))))
