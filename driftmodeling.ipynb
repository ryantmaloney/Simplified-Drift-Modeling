# %%
import simpledrift as sd
import imp
imp.reload(sd)
# Out:
# <module 'simpledrift' from '/Users/athenaye/Documents/GitHub/Simplified-Drift-Modeling/simpledrift.py'>

# %%
import simpledrift as sd
import imp
imp.reload(sd)

#driftmodeling(flynum, numberofbins, numberofdays, prefmean, prefvariance, envimean, envivariance, driftvariance, gain, per)
flynum=1000
numberofbins=100
numberofdays=30
prefmean=0
prefvariance=.03
envimean=0
envivariance=.1
driftvariance=.1
gain=.4
per=20
deathrate=1
birthrate=4.5
matureage=0
sd.driftmodeling(flynum, numberofbins, numberofdays, prefmean, prefvariance, envimean, envivariance, driftvariance, gain, per,deathrate,birthrate,matureage)
# Out:
# 452.8167185542236
# 910.1130536188246
# 470.5880620815908
# 1430.1977040604395
# 298.11025661865926
# 980.3981341106427
# 264.6672130779592
# 654.761951386749
# 311.5239619106512
# 642.4196040939216
# 452.0584422504089
# 872.822297969676
# 672.4805511688456
# 1391.8329116748369
# 1221.6853235822525
# 3002.7606988917883
# 7741.777000509349
# 15355.991155243079
# 74274.02173945798
# 128633.58985617847
# 319236.8790278209
# 640773.7286233822
# 334701.6110020754
# 1012587.7300722596
# 212172.30925134112
# 696191.9469774071
# 188377.9100045225
# 465692.385339941
# 221754.6954991247
# 457209.052798355
# 321792.37501187454
# 621280.2295244304
# 478662.540568126
# 990695.9059842842
# 869535.6000674214
# 2137265.4754929934
# 5510336.448839349
# 10929875.531891473
# 52865761.17970223
# 91557078.48664847
# 227222110.00717086
# 456081263.2769686
# 238229388.05602336
# 720726006.473712
# 151017138.0304174
# 495526092.7475521
# 134081082.19966337
# 331464230.6213662
# 157837559.37291604
# 325426078.83312076
# 229041026.53771806
# 442206443.0010973
# 340695952.33298105
# 705144139.2523143
# 618906294.6166432
# 1521233927.5609145
# 3922072786.169525
# 7779519050.761901

# %%
import simpledrift as sd
import imp
imp.reload(sd)

#driftmodeling(flynum, numberofbins, numberofdays, prefmean, prefvariance, envimean, envivariance, driftvariance, gain, per)
flynum=1000
numberofbins=100
numberofdays=30
prefmean=0
prefvariance=1
envimean=0
envivariance= .1
driftvariance=.001
gain=.4
per=20
deathrate=.90
birthrate=3
sd.driftmodeling(flynum, numberofbins, numberofdays, prefmean, prefvariance, envimean, envivariance, driftvariance, gain, per, deathrate, birthrate, matureage)
# Out:
# 136.85358984398076
# 273.70717968796157
# 243.87748101879404
# 487.75496203758803
# 416.2383605687455
# 832.4767211374909
# 759.7524409935864
# 1519.5048819871727
# 1566.4534308337177
# 3132.9068616674354
# 3528.8362528336284
# 7057.672505667257
# 7734.334798633362
# 15468.669597266724
# 13965.292447293337
# 27930.58489458667
# 21390.946111368223
# 42781.892222736446
# 32368.779797794487
# 64737.55959558897
# 48820.15276222051
# 97640.305524441
# 75614.82878156716
# 151229.65756313436
# 126020.24708593548
# 252040.49417187096
# 232204.74692757372
# 464409.49385514745
# 481318.6157634963
# 962637.2315269924
# 1086313.9014722789
# 2172627.8029445577
# 2382320.4672333
# 4764640.934466599
# 4299249.868309958
# 8598499.736619918
# 6583337.003225963
# 13166674.006451925
# 9963491.917463157
# 19926983.834926315
# 15026958.314911524
# 30053916.629823048
# 23274363.191537302
# 46548726.38307461
# 38789351.44618283
# 77578702.89236565
# 71473220.78526075
# 142946441.5705215
# 148151076.27182457
# 296302152.54364914
# 334370110.342419
# 668740220.6848382
# 733284154.8370725
# 1466568309.674145
# 1323319878.5815735
# 2646639757.1631474
# 2026367629.421963
# 4052735258.843926

# %%
import simpledrift as sd
import imp
imp.reload(sd)

#driftmodeling(flynum, numberofbins, numberofdays, prefmean, prefvariance, envimean, envivariance, driftvariance, gain, per)
flynum=1
numberofbins=100
numberofdays=30
prefmean=0
prefvariance=.03
envimean=0
envivariance= .1
driftvariance=.001
gain=.4
per=20
deathrate=1
birthrate=24

sd.driftmodeling(flynum, numberofbins, numberofdays, prefmean, prefvariance, envimean, envivariance, driftvariance, gain, per, deathrate, birthrate, matureage)
# Out:
# 0.4528167185542236
# 0.9056334371084473
# 1.6470747928189138
# 3.2941495856378276
# 0.6351755362642463
# 1.2703510725284926
# 0.040141708008656
# 0.08028341601731201
# 0.0012935408437237644
# 0.0025870816874475288
# 8.470691899225222e-05
# 0.00016941383798450445
# 3.405080809175785e-05
# 6.81016161835157e-05
# 0.0001270131674059954
# 0.0002540263348119908
# 0.002904313140082855
# 0.005808626280165709
# 0.13279575220531614
# 0.2655915044106324
# 3.0058821714843957
# 6.011764342968792
# 10.932881132454698
# 21.86576226490939
# 4.216088014468106
# 8.432176028936215
# 0.266446536597144
# 0.5328930731942881
# 0.00858605085964068
# 0.017172101719281355
# 0.0005622526623725915
# 0.0011245053247451835
# 0.0002260162474722223
# 0.0004520324949444447
# 0.0008430646588659188
# 0.0016861293177318376
# 0.01927771580864514
# 0.03855543161729029
# 0.881447230193864
# 1.7628944603877277
# 19.951892062498
# 39.90378412499601
# 72.56826842918099
# 145.13653685836198
# 27.984773917163384
# 55.96954783432676
# 1.7685698358512418
# 3.5371396717024832
# 0.05699090989651039
# 0.11398181979302077
# 0.0037320173551464854
# 0.0074640347102929725
# 0.0015002090955906395
# 0.003000418191181279
# 0.005595939599683475
# 0.011191879199366945
# 0.1279580778894898
# 0.2559161557789796

# %%
import simpledrift as sd
import imp
imp.reload(sd)

#driftmodeling(flynum, numberofbins, numberofdays, prefmean, prefvariance, envimean, envivariance, driftvariance, gain, per)
flynum=1
numberofbins=100
numberofdays=60
prefmean=0
prefvariance=.001
envimean=0
envivariance= .1
driftvariance=.001
gain=.4
per=40
deathrate=.5
birthrate=0
sd.driftmodeling(flynum, numberofbins, numberofdays, prefmean, prefvariance, envimean, envivariance, driftvariance, gain, per,deathrate,birthrate)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-23c48dfa768b> in <module>
#      16 deathrate=.5
#      17 birthrate=0
# ---> 18 sd.driftmodeling(flynum, numberofbins, numberofdays, prefmean, prefvariance, envimean, envivariance, driftvariance, gain, per,deathrate,birthrate)
#
# TypeError: driftmodeling() missing 1 required positional argument: 'matureage'

# %%
import simpledrift as sd
import imp
imp.reload(sd)

#driftmodeling(flynum, numberofbins, numberofdays, prefmean, prefvariance, envimean, envivariance, driftvariance, gain, per)
flynum=1000
numberofbins=100
numberofdays=30
prefmean=0
prefvariance=.001
envimean=0
envivariance= .1
driftvariance=.1
gain=.4
per=20
deathrate=1
birthrate=24
sd.driftmodeling(flynum, numberofbins, numberofdays, prefmean, prefvariance, envimean, envivariance, driftvariance, gain, per, deathrate, birthrate, matureage)
# Out:
# 445.04352341242327
# 904.6121791999733
# 1490.5247585418565
# 5398.644884462368
# 1491.5697744447846
# 9074.660311660055
# 1813.574761954123
# 8007.08060018373
# 2600.262373901821
# 7725.629960641415
# 4334.679986594948
# 11412.260636728293
# 8929.214366796448
# 28695.996529041287
# 59541.27604689785
# 191003.48624319822
# 2166549.9167137993
# 4378087.260544713
# 103319285.26710139
# 176741425.25173438
# 1967712792.5483832
# 3996912528.761238
# 6591662360.43089
# 23863487563.91776
# 6595187754.460812
# 40116298358.250046
# 8018381800.60127
# 35398782899.06868
# 11496346835.907204
# 34155726162.289055
# 19164441551.608124
# 50455301493.40608
# 39477405204.592674
# 126869302613.21736
# 263240612917.13638
# 844454604545.0928
# 9578636942446.236
# 19356169927215.695
# 456789808918390.6
# 781399926044147.0
# 8699548667670734.0
# 1.7670940188057416e+16
# 2.914271214914762e+16
# 1.055040004968682e+17
# 2.9158298436458588e+16
# 1.7736007574685645e+17
# 3.545044936154493e+16
# 1.5650324365067978e+17
# 5.082704609033504e+16
# 1.510075063564666e+17
# 8.472882455117786e+16
# 2.2307033452548275e+17
# 1.7453543482119562e+17
# 5.60907911305236e+17
# 1.1638256009980639e+18
# 3.733458438495929e+18
# 4.234856761936268e+19
# 8.557648399661072e+19
